# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("India_Unemployment_Synthetic_Dataset_100k.csv")
df
# Out:
#       Student_ID  Graduation_Year        State  Gender  Age Degree_Level  \
# 0       ST000001             2018       Kerala    Male   33           UG
# 1       ST000002             2017    Karnataka  Female   30           UG
# 2       ST000003             2021        Delhi  Female   23           UG
# 3       ST000004             2021  Maharashtra    Male   23           UG
# 4       ST000005             2018    Telangana    Male   27           PG
# ...          ...              ...          ...     ...  ...          ...
# 99995   ST099996             2019  Maharashtra  Female   27           PG
# 99996   ST099997             2020    Rajasthan  Female   26           PG
# 99997   ST099998             2022   Tamil Nadu  Female   23           UG
# 99998   ST099999             2024      Gujarat  Female   34           PG
# 99999   ST100000             2019    Karnataka  Female   21           UG
#
#        Degree            Stream College_Type College_Tier  CGPA Internship  \
# ...

# %%
df = df.drop(['Student_ID', 'Urban_Rural' , 'Job_Search_Months'], axis=1)
df
# Out:
#        Graduation_Year        State  Gender  Age Degree_Level  Degree  \
# 0                 2018       Kerala    Male   33           UG   B.Com
# 1                 2017    Karnataka  Female   30           UG    B.Sc
# 2                 2021        Delhi  Female   23           UG   B.Com
# 3                 2021  Maharashtra    Male   23           UG    B.Sc
# 4                 2018    Telangana    Male   27           PG     MCA
# ...                ...          ...     ...  ...          ...     ...
# 99995             2019  Maharashtra  Female   27           PG     MCA
# 99996             2020    Rajasthan  Female   26           PG     MCA
# 99997             2022   Tamil Nadu  Female   23           UG    B.Sc
# 99998             2024      Gujarat  Female   34           PG     MBA
# 99999             2019    Karnataka  Female   21           UG  B.Tech
#
#                  Stream College_Type College_Tier  CGPA Internship  \
# ...

# %%
print('Shape:', df.shape)
print('\nDegrees:', df.Degree.unique())
print('\n:Salary_LPA', df.Salary_LPA.unique())
df.describe()
# Out:
# Shape: (100000, 15)
#
# Degrees: ['B.Com' 'B.Sc' 'MCA' 'MBBS' 'B.Tech' 'MBA' 'BA' 'M.Tech']
#
# :Salary_LPA [ 5.93 15.37  0.   ... 15.86  5.59 18.92]
#        Graduation_Year            Age           CGPA   Skills_Score  \
# count    100000.000000  100000.000000  100000.000000  100000.000000
# mean       2020.996240      27.496850       7.494895      50.582380
# std           2.583225       4.608011       1.443271      28.904252
# min        2017.000000      20.000000       5.000000       1.000000
# 25%        2019.000000      23.000000       6.230000      25.000000
# 50%        2021.000000      28.000000       7.500000      51.000000
# 75%        2023.000000      31.000000       8.740000      76.000000
# max        2025.000000      35.000000      10.000000     100.000000
#
#           Salary_LPA
# count  100000.000000
# mean        7.441278
# std         8.095047
# min         0.000000
# 25%         0.000000
# 50%         4.900000
# 75%        14.490000
# max        24.000000
